# %%
a = dict()

# %%
a.setdefault(1,2)
# Out:
# 2

# %%
a
# Out:
# {1: 2}

# %%
a.setdefault(2,3)
# Out:
# 3

# %%
a.setdefault(3,0)
# Out:
# 0

# %%
a = sorted(a.items(), key=lambda x:x[1],reverse=True)

# %%
a
# Out:
# [(2, 3), (1, 2), (3, 0)]
